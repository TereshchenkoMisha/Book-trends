# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('c:\\data_vis\\data\\raw\\goodreads_dataset.csv');
# Out:
# C:\Users\79378\AppData\Local\Temp\ipykernel_33916\1402054068.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('c:\\data_vis\\data\\raw\\goodreads_dataset.csv');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98765 entries, 0 to 98764
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   book_id           98765 non-null  int64
#  1   title             98765 non-null  object
#  2   author            98765 non-null  object
#  3   rating            98765 non-null  float64
#  4   ratings_count     98765 non-null  int64
#  5   reviews_count     98765 non-null  int64
#  6   description       94912 non-null  object
#  7   genres            71513 non-null  object
#  8   pages             95409 non-null  float64
#  9   format            98492 non-null  object
#  10  publication_date  98481 non-null  object
#  11  literary_awards   11744 non-null  object
#  12  original_title    92832 non-null  object
#  13  series            21862 non-null  object
#  14  setting           15169 non-null  object
#  15  characters        17483 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['book_id', 'title', 'author', 'rating', 'ratings_count',
#        'reviews_count', 'description', 'genres', 'pages', 'format',
#        'publication_date', 'literary_awards', 'original_title', 'series',
#        'setting', 'characters', 'isbn', 'language'],
#       dtype='object')

# %%
df['description'].isna().sum()
# Out:
# np.int64(3853)
